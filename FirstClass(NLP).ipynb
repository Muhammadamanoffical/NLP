# %% [raw]
# #NLU(natural language understanding)
#   #-----pre-processing----------:
#   #step1:
#     #-first load then convvert into lowercase
#   #step2:
#     #-remove number
#   #step3:
#     #-remove HTML tags
#   #step4:
#     # remove Emoji  and punctuation
#   #step5:
#     #Remove stop watch
#   #step6:
#     #Apply Bag of Words (BoW)  past version
#   #step7:
#     #TF-IDF (Term Frequency-Inverse Document Frequency) technique of (BoW)
#   #-----------how we will work-------:
#     #-Sentiment analysis
#     #-next word prediction
#     #-machine translation
#     #-speech recognition

# %%
text='''
NLP (Natural Language Processing) is an AI field enabling computers to understand, interpret, and generate human language (text/speech) by combining computer science, linguistics, and machine learning, powering tools like translation, chatbots, voice assistants (Siri, Alexa), and spam filters, making human-computer interaction seamless. 
What NLP Does:
Understands & Processes: Reads and comprehends human text and speech, identifying meaning, sentiment, and intent.
Generates: Creates human-like text for responses, summaries, or translations.
Analyzes: Extracts insights from large volumes of text data (social media, emails). 
Common Examples & Applications:
Virtual Assistants: Siri, Alexa, Google Assistant.
Translation: Google Translate, automatic language conversion.
Text Summarization: Condensing long articles.
Spam Filters: Identifying unwanted emails.
Autocorrect & Grammar Checkers: Improving written communication.
Chatbots & Customer Service: Automating support. 
How it Works:
Uses computational linguistics, machine learning, and deep learning.
Combines rules-based models with statistical analysis to decipher language structure, grammar, and context. 
Key Areas:
Speech Recognition
Text Classification
Natural Language Understanding (NLU)
Natural Language Generation (NLG) 
'''

# %%
text
# Out:
# '\nNLP (Natural Language Processing) is an AI field enabling computers to understand, interpret, and generate human language (text/speech) by combining computer science, linguistics, and machine learning, powering tools like translation, chatbots, voice assistants (Siri, Alexa), and spam filters, making human-computer interaction seamless. \nWhat NLP Does:\nUnderstands & Processes: Reads and comprehends human text and speech, identifying meaning, sentiment, and intent.\nGenerates: Creates human-like text for responses, summaries, or translations.\nAnalyzes: Extracts insights from large volumes of text data (social media, emails). \nCommon Examples & Applications:\nVirtual Assistants: Siri, Alexa, Google Assistant.\nTranslation: Google Translate, automatic language conversion.\nText Summarization: Condensing long articles.\nSpam Filters: Identifying unwanted emails.\nAutocorrect & Grammar Checkers: Improving written communication.\nChatbots & Customer Service: Automating support. \nHo
# ...

# %% [markdown]
# # step 1: text into lower

# %%
text=text.lower()

# %% [markdown]
# # step 2: remove number

# %%
import re
import warnings
warnings.filterwarnings('ignore')

# %%
m="usman444usman33"

# %%
re.sub("\d+"," ",m)
# Out:
# 'usman usman '

# %% [markdown]
# # step3:punctuation

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#word madding
text.split()
# Out:
# ['nlp',
#  '(natural',
#  'language',
#  'processing)',
#  'is',
#  'an',
#  'ai',
#  'field',
#  'enabling',
#  'computers',
#  'to',
#  'understand,',
#  'interpret,',
#  'and',
#  'generate',
#  'human',
#  'language',
#  '(text/speech)',
#  'by',
#  'combining',
#  'computer',
#  'science,',
#  'linguistics,',
#  'and',
#  'machine',
#  'learning,',
#  'powering',
#  'tools',
#  'like',
#  'translation,',
#  'chatbots,',
#  'voice',
#  'assistants',
#  '(siri,',
#  'alexa),',
#  'and',
#  'spam',
#  'filters,',
#  'making',
#  'human-computer',
#  'interaction',
#  'seamless.',
#  'what',
#  'nlp',
#  'does:',
#  'understands',
#  '&',
#  'processes:',
#  'reads',
#  'and',
#  'comprehends',
#  'human',
#  'text',
#  'and',
#  'speech,',
#  'identifying',
#  'meaning,',
#  'sentiment,',
#  'and',
#  'intent.',
#  'generates:',
#  'creates',
#  'human-like',
#  'text',
#  'for',
#  'responses,',
#  'summaries,',
#  'or',
#  'translations.',
#  'analyzes:',
#  'extracts',
# ...

# %%
test="amanaa!#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~"

# %%
[m for m in test if m not in string.punctuation]
# Out:
# ['a', 'm', 'a', 'n', 'a', 'a']

# %%
"".join([m for m in test if m not in string.punctuation])
# Out:
# 'amanaa'

# %%
#apply on actual text paragraph
text="".join([m for m in text if m not in string.punctuation])

# %%
 text
# Out:
# '\nnlp natural language processing is an ai field enabling computers to understand interpret and generate human language textspeech by combining computer science linguistics and machine learning powering tools like translation chatbots voice assistants siri alexa and spam filters making humancomputer interaction seamless \nwhat nlp does\nunderstands  processes reads and comprehends human text and speech identifying meaning sentiment and intent\ngenerates creates humanlike text for responses summaries or translations\nanalyzes extracts insights from large volumes of text data social media emails \ncommon examples  applications\nvirtual assistants siri alexa google assistant\ntranslation google translate automatic language conversion\ntext summarization condensing long articles\nspam filters identifying unwanted emails\nautocorrect  grammar checkers improving written communication\nchatbots  customer service automating support \nhow it works\nuses computational linguistics machine lear
# ...

# %% [markdown]
# # step 4(Remove stopwatch)

# %%
import nltk
from nltk.corpus import stopwords

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stopwords.words("english")
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
test="hello have himself above"

# %%
"".join([m for m in test.split() if m not in  stopwords.words("english") ])
# Out:
# 'hello'

# %%
#apply Remove stopwords from actual text
text="".join([m for m in text.split() if m not in  stopwords.words("english") ])

# %%
text
# Out:
# '...'
